# %%
a = 10
b = 20

# %%
a+b
# Out:
# 30

# %%
a-b
# Out:
# -10

# %%
a*b
# Out:
# 200

# %%
a/b
# Out:
# 0.5

# %%
a//b
# Out:
# 0

# %%
a%b
# Out:
# 10

# %%
a**b
# Out:
# 100000000000000000000

# %%
10//2
# Out:
# 5

# %%
a = 10
a //= 2

# %%
a
# Out:
# 5

# %%
a= 4
lit = [2,3,4]
a in lit
# Out:
# True

# %%
b= 2

# %%
 a is b
# Out:
# False
