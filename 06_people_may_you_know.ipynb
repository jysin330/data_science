# %%
import json

# %%
data = None
with open("data3.json", "r") as f:
    data = json.load(f)
data
# Out:
# {'users': [{'id': 1,
#    'name': 'Amit',
#    'friends': [2, 3, 4, 5, 6],
#    'liked_pages': [101, 102]},
#   {'id': 2,
#    'name': 'Priya',
#    'friends': [1, 3, 5, 6, 7],
#    'liked_pages': [102, 103]},
#   {'id': 3,
#    'name': 'Rahul',
#    'friends': [1, 2, 4, 7, 8],
#    'liked_pages': [101, 103]},
#   {'id': 4, 'name': 'Sara', 'friends': [1, 3, 6, 8, 9], 'liked_pages': [104]},
#   {'id': 5,
#    'name': 'Neha',
#    'friends': [1, 2, 6, 10, 11],
#    'liked_pages': [102, 105]},
#   {'id': 6,
#    'name': 'Vikram',
#    'friends': [1, 2, 4, 5, 12],
#    'liked_pages': [106]},
#   {'id': 7,
#    'name': 'Kunal',
#    'friends': [2, 3, 8, 9, 13],
#    'liked_pages': [101, 107]},
#   {'id': 8,
#    'name': 'Anjali',
#    'friends': [3, 4, 7, 10, 14],
#    'liked_pages': [103, 108]},
#   {'id': 9,
#    'name': 'Ravi',
#    'friends': [4, 7, 10, 11, 15],
#    'liked_pages': [104, 109]},
#   {'id': 10,
#    'name': 'Sneha',
#    'friends': [5, 8, 9, 12, 16],
# ...

# %%
def find_people_you_may_know(user_id, data):
    users_friend = {}
    for user in data["users"]:
        users_friend[user["id"]] = user["friends"]

    if user_id not in users_friend:
        return []
    direct_friend = users_friend[user_id]
    recommanded_friend = {}

    for friend in direct_friend:
        print(f"{users_friend[friend]}")
        for mutual in users_friend[friend]:
            if mutual != user_id and mutual not in direct_friend:
                recommanded_friend[mutual] = recommanded_friend.get(mutual , 0) + 1

    sorted_suggestions = sorted(recommanded_friend.items(), key=lambda x: x[1], reverse=True)
    return [user_id for user_id, _ in sorted_suggestions]

            

user_id = 10  # Example: Finding suggestions for Amit
recommendations = find_people_you_may_know(user_id, data)
recommendations
# Out:
# [1, 2, 6, 10, 11]
# [3, 4, 7, 10, 14]
# [4, 7, 10, 11, 15]
# [6, 10, 11, 13, 18]
# [10, 14, 15, 18, 22]
# [11, 6, 4, 7, 14, 15, 18, 1, 2, 3, 13, 22]
