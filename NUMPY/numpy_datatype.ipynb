# %%
import numpy as np
arr = np.array([1,2,3,4,5])
arr.dtype
# Out:
# dtype('int64')

# %%
arr.astype("float64")
# Out:
# array([1., 2., 3., 4., 5.])

# %%
arr2 = np.array([1,2,3,4,5], dtype="float32")
arr2
# Out:
# array([1., 2., 3., 4., 5.], dtype=float32)

# %%
arr2.nbytes
# Out:
# 20

# %%
arr.nbytes
# Out:
# 40

# %%
arr_int64 = np.array([1,2,3], dtype=np.int64)
arr_int32 = np.array([1,2,3], dtype=np.int32)
print(f"{arr_int64.nbytes}")
print(f"{arr_int32.nbytes}")
# Out:
# 24
# 12
